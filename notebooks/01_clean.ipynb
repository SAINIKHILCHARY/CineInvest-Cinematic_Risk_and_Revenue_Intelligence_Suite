# %%
import pandas as pd
import numpy as np
import os

df = pd.read_csv( 
    r"C:\Users\91934\OneDrive\Desktop\DA\ZDIP\data\cleaned\project_dataset_cleaned.csv"
)

# %%
print("Rows and Columns:", df.shape)
print("\nData Types:\n")
print(df.dtypes)
# Out:
# Rows and Columns: (4803, 51)
#
# Data Types:
#
# movie_id                              int64
# title                                object
# Budget                              float64
# Revenue                             float64
# Popularity                          float64
# Genres                               object
# Primary_Genre                        object
# Genre_Count                           int64
# Director                             object
# Production_Companies                 object
# Primary_Production_Company           object
# Production_Company_Count              int64
# Release_Date                         object
# Cast_Count                            int64
# Lead_Actor                           object
# Second_Lead_Actor                    object
# Third_Lead_Actor                     object
# Male_Cast_Count                       int64
# Female_Cast_Count                     int64
# Unknown_Cast_Gender_Count             int64
# ...

# %%
print("\nMissing Values:\n")
print(df.isnull().sum())
# Out:
# Missing Values:
#
# movie_id                              0
# title                                 0
# Budget                              564
# Revenue                             736
# Popularity                            8
# Genres                                0
# Primary_Genre                         0
# Genre_Count                           0
# Director                              0
# Production_Companies                  0
# Primary_Production_Company            0
# Production_Company_Count              0
# Release_Date                          8
# Cast_Count                            0
# Lead_Actor                            0
# Second_Lead_Actor                     0
# Third_Lead_Actor                      0
# Male_Cast_Count                       0
# Female_Cast_Count                     0
# Unknown_Cast_Gender_Count             0
# Cast_Gender_Ratio                   307
# Crew_Count                            0
# Producer_Count                        0
# ...

# %%
duplicates = df.duplicated().sum()

print("\nDuplicate Rows:", duplicates)

# Remove duplicates
df = df.drop_duplicates()
# Out:
# Duplicate Rows: 0

# %%
text_columns = df.select_dtypes(include="object").columns

for col in text_columns:
    df[col] = df[col].astype(str).str.strip()

# %%
if "Release_Date" in df.columns:
    df["Release_Date"] = pd.to_datetime(
        df["Release_Date"],
        format="%Y-%m-%d",
        errors="coerce"
    )

# %%
if "Release_Date" in df.columns:
    df["Release_Year"] = df["Release_Date"].dt.year

# %%
print("\nFinal Row Count:", len(df))
# Out:
# Final Row Count: 4803

# %%
df.to_csv("cleaned_movies.csv", index=False)

print("\nDataset cleaned and saved successfully!")
# Out:
# Dataset cleaned and saved successfully!

# %% [markdown]
# #### Assert row count

# %%
expected_rows = 4803

actual_rows = len(df)

assert actual_rows == expected_rows, (
    f"Row count mismatch! "
    f"Expected: {expected_rows}, "
    f"Got: {actual_rows}"
)

print("✓ Row count matches the cleaning plan.")
# Out:
# ✓ Row count matches the cleaning plan.

# %%
expected_nulls = {
    "Budget": 564,
    "Revenue": 736,
    "Second_Lead_Actor": 0,
    "Third_Lead_Actor": 0
}

for column, expected in expected_nulls.items():
    actual = df[column].isnull().sum()

    assert actual == expected, (
        f"{column}: Expected {expected}, Got {actual}"
    )

print("✓ Null counts match the cleaning plan.")
# Out:
# ✓ Null counts match the cleaning plan.

# %%
null_counts = df.isnull().sum()

print(null_counts[null_counts > 0])
# Out:
# Budget                   564
# Revenue                  736
# Popularity                 8
# Release_Date            4803
# Cast_Gender_Ratio        307
# Profit                   869
# ROI                      869
# Revenue_Budget_Ratio     869
# Release_Year            4803
# Release_Month              8
# dtype: int64

# %%
df.to_csv("cleaned_movies.csv", index=False)

print("✓ Cleaned dataset saved.")
# Out:
# ✓ Cleaned dataset saved.
