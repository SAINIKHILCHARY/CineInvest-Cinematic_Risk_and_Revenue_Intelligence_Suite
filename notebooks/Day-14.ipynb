# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(
    r"C:\Users\91934\OneDrive\Desktop\DA\ZDIP\data\cleaned\cleaned_movies.csv"
)

# %%
columns = ["Revenue", "Genre_Count", "Production_Company_Count"]

df[columns].describe()
# Out:
#             Revenue  Genre_Count  Production_Company_Count
# count  4.067000e+03  4803.000000               4803.000000
# mean   1.043237e+08     2.565064                  3.209452
# std    1.748430e+08     1.004200                  1.991407
# min    1.300000e+01     0.000000                  0.000000
# 25%    1.144172e+07     2.000000                  2.000000
# 50%    4.140000e+07     3.000000                  3.000000
# 75%    1.204534e+08     3.000000                  4.000000
# max    2.923706e+09     7.000000                 17.000000

# %%
for col in columns:
    plt.figure(figsize=(6,4))
    plt.hist(df[col], bins=30)
    plt.title(f"{col} Distribution")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %% [markdown]
# #### Skewness

# %%
for col in columns:
    print(col, "Skewness:", df[col].skew())
# Out:
# Revenue Skewness: 4.37767853990672
# Genre_Count Skewness: 0.3046061930548046
# Production_Company_Count Skewness: 1.4030041100531603

# %% [markdown]
# #### Kurtosis

# %%
for col in columns:
    print(col, "Kurtosis:", df[col].kurt())
# Out:
# Revenue Kurtosis: 34.152477125285145
# Genre_Count Kurtosis: 0.06282310165998295
# Production_Company_Count Kurtosis: 3.8241583052541848

# %% [markdown]
# ##### Sampling Caveats
#
# Document the following limitations:
#
# - The dataset contains missing values in some attributes.
# - Revenue has extreme values that can influence statistical measures.
# - Some genres and production companies have very few observations.
# - The dataset represents only the available movie records and may not include every
# - movie, so results may not generalize to the entire film industry.
# - Statistical conclusions should be interpreted with these sampling limitations in mind.
